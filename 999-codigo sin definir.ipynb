// %%
public class Casa 
{
  public int X {get; private set;}
  public int Y {get; private set;}
  
  public Casa(int x, int y)
  {
    X = x; Y = y;
  }
  public void Mostrar()
  {
    Console.WriteLine($"Casa: {X} {Y}");
  }
}

Casa simpsons = new Casa(100, 100);

=================================

public abstract class ItemJuego
{
  public int X {get; protected set;}
  public int Y {get; protected set;}
  public ItemJuego(int x, int y)
  {
    X = x; Y = y;
  }
  public abstract void Mostrar();
}

//  no vamos a poder crear una instancia de ItemJuego
//  es necesario el ctor de ItemJuego?

public class Personaje : ItemJuego
{
  public string Nombre {get; private set;}
  public Personaje(string nombre) : base(0,0) 
  {
    Nombre = nombre;
  }

  public override void Mostrar()
  {
    Console.WriteLine($"Personaje: [{Nombre}] {X} {Y}");
  }
  public void Mover(int x, int y)
  {
    X = x; Y = y;    
  }
}

public class Casa : ItemJuego
{
  public Casa() : base(0, 0) {}
  public override void Mostrar()
  {
    Console.WriteLine($"Casa: {X} {Y}");
  }
}

Personaje homer = new ("Homero");
Personaje marge = new Personaje("Marge");
Casa simpsons = new Casa();

homer.Mostrar();
marge.Mostrar();
//  marge.X = 200;
//  marge.Mover(200, 20);
//  marge.Mostrar();
simpsons.Mostrar();




=================================

public class Personaje : ItemJuego
{
  public string Nombre {get; set;}
  public Casa Residencia {get; set;}
  public Personaje(string nombre) : base(0,0) 
  {
    Nombre = nombre;
  }
  public override void Mostrar()
  {
    Console.WriteLine($"Personaje: [{Nombre}] {X} {Y}");
    if (Residencia != null)
    {
      Console.Write("Vive en ");
      Residencia.Mostrar();
    }
  }
  public void Mover(int x, int y)
  {
    X = x; Y = y;    
  }
}

Personaje homer = new ("Homero");
Personaje marge = new Personaje("Marge");

homer.Mostrar();
marge.Mostrar();


=================================

Personaje homer = new Personaje("Homero") { Residencia = new Casa() };

homer.Mostrar();


=================================

List<ItemJuego> items = new List<ItemJuego>();

items.Add(new Personaje("Homero"));
items.Add(new Casa());
items.Add(new Personaje("Marge"));

foreach (var it in items)
  it.Mostrar();


=================================

foreach (var it in items)
{
  Personaje p = (Personaje)it;
  p.Nombre = $"{p.Nombre}-{Guid.NewGuid()}";
}



=================================

foreach (var it in items)
{
  Personaje p = it as Personaje;
  if (p != null)
    p.Nombre = $"{p.Nombre}-{Guid.NewGuid()}";
}

foreach (var it in items)
  it.Mostrar();

foreach (var it in items)
{
  if (it is Personaje p)
    p.Nombre = $"{p.Nombre}-{Guid.NewGuid()}";
}

foreach (var it in items)
  it.Mostrar();



=================================
