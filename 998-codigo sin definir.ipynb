// %%
public abstract class ItemJuego
{
  public int X {get; protected set;}
  public int Y {get; protected set;}
  public ItemJuego(int x, int y)
  {
    X = x; Y = y;
  }
  public abstract void Mostrar();
}

public class Casa : ItemJuego
{
  public Casa() : base(0, 0) {}
  public override void Mostrar()
  {
    Console.WriteLine($"Casa: {X} {Y}");
  }
}

public class Personaje : ItemJuego
{
  public string Nombre {get; set;}
  public Casa Residencia {get; set;}
  public Personaje(string nombre) : base(0,0) 
  {
    Nombre = nombre;
  }
  public override void Mostrar()
  {
    Console.WriteLine($"Personaje: [{Nombre}] {X} {Y}");
    if (Residencia != null)
    {
      Console.Write("Vive en ");
      Residencia.Mostrar();
    }
  }
  public void Mover(int x, int y)
  {
    X = x; Y = y;    
  }
}

Personaje homer = new ("Homero");
Personaje marge = new Personaje("Marge");
Personaje bart = new Personaje("Bart");
homer.Hijos.Add(bart);  //  no tiene set...pero funciona...por que?
homer.Hijos.Add(bart);
homer.Mostrar();

==============================

public class Personaje : ItemJuego
{
  public string Nombre {get; set;}
  public Casa Residencia {get; set;}
  public HashSet<Personaje> Hijos {get;}

  public Personaje(string nombre) : base(0,0) 
  {
    Nombre = nombre;
    Hijos = new HashSet<Personaje>();
  }
  public override void Mostrar()
  {
    Console.WriteLine($"Personaje: [{Nombre}] {X} {Y}");
    if (Residencia != null)
    {
      Console.Write("Vive en ");
      Residencia.Mostrar();
    }
    if (Hijos.Count != 0)
    {
      Console.WriteLine($"Hijos de {Nombre}");

      foreach (var h in Hijos)
        h.Mostrar();
    }
      
  }
  public void Mover(int x, int y)
  {
    X = x; Y = y;    
  }
}

Personaje homer = new ("Homero");
Personaje marge = new Personaje("Marge");
Personaje bart = new Personaje("Bart");
Personaje lisa = bart;
homer.Hijos.Add(bart);  //  no tiene set...pero funciona...por que?
homer.Hijos.Add(bart);
homer.Hijos.Add(bart);
homer.Hijos.Add(lisa);
lisa = new Personaje("Lisa");
homer.Hijos.Add(lisa);
homer.Mostrar();



List<ItemJuego> items = new List<ItemJuego>();
Vehiculo auto = new Vehiculo(50, 15);

items.Add(new Personaje("Homero", 100, 100));
items.Add(new Personaje("Marge", -400, -900));
items.Add(new Casa(300, 20));
items.Add(new Personaje("Bart", 30, 20));
items.Add(auto);
items.Add(new Personaje("Maggie", 10, 10));
items.Add(new Personaje("Lisa"));
items.Add(new Casa(100, -50));

================ DELEGADO ANONIMO

List<ItemJuego> HallarCercanos(ItemJuego origen, float distancia)
{
  Predicate<ItemJuego> pp = delegate(ItemJuego item)
  {
    int dX = (item.X - origen.X) * (item.X - origen.X);
    int dY = (item.Y - origen.Y) * (item.Y - origen.Y);
    float dist = MathF.Sqrt(dX + dY);

    return dist <= distancia;
  };
  
  return items.FindAll(pp);
}

var resultado = HallarCercanos(auto, 20);

foreach (var item in resultado)
  item.Mostrar();

List<ItemJuego> items = new List<ItemJuego>();
Vehiculo auto = new Vehiculo(50, 15);

items.Add(new Personaje("Homero", 100, 100));
items.Add(new Personaje("Marge", -400, -900));
items.Add(new Casa(300, 20));
items.Add(new Personaje("Bart", 30, 20));
items.Add(auto);
items.Add(new Personaje("Maggie", 10, 10));
items.Add(new Personaje("Lisa"));
items.Add(new Casa(100, -50));

================ CON FUNCION LOCAL

List<ItemJuego> HallarCercanos(ItemJuego origen, float distancia)
{
  return items.FindAll(Cercano);

  bool Cercano(ItemJuego item)
  {
    int dX = (item.X - origen.X) * (item.X - origen.X);
    int dY = (item.Y - origen.Y) * (item.Y - origen.Y);
    float dist = MathF.Sqrt(dX + dY);

    return dist <= distancia;
  }
}

var resultado = HallarCercanos(auto, 20);

foreach (var item in resultado)
  item.Mostrar();


: IComparable<ItemJuego>

  public int CompareTo(ItemJuego otra)
  {
    float modulo = MathF.Sqrt(X*X+Y*Y);
    float moduloOtra = MathF.Sqrt(otra.X*otra.X+otra.Y*otra.Y);
    
    return (int)(modulo - moduloOtra);
  }


items.ForEach(Imprimir);


void Imprimir(ItemJuego x)
{
  x.Mostrar();
}
